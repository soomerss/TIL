# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 10.0 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf
from datetime import datetime

ticket = yf.Ticker("AAPL")
data = ticket.history()
# Out:
# (Timestamp('2023-05-08 00:00:00-0400', tz='America/New_York'), Open            1.722418e+02
# High            1.736099e+02
# Low             1.718723e+02
# Close           1.732603e+02
# Volume          5.596280e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2023-05-08 00:00:00-04:00, dtype: float64)
# (Timestamp('2023-05-09 00:00:00-0400', tz='America/New_York'), Open            1.728110e+02
# High            1.733003e+02
# Low             1.713630e+02
# Close           1.715327e+02
# Volume          4.532690e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2023-05-09 00:00:00-04:00, dtype: float64)
# (Timestamp('2023-05-10 00:00:00-0400', tz='America/New_York'), Open            1.727810e+02
# High            1.737896e+02
# Low             1.716626e+02
# Close           1.733203e+02
# Volume          5.372450e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2023-05-10 00:00:00-04:00, dtype: float64)
# ...

# %%
for index,row in data.iterrows():
    print(index.strftime('%Y-%m-%d %H:%M:%S'),row['Open'],row['High'],row['Low'],row['Close'],row['Volume'])
#     print(i.strftime('%Y-%m-%d %H:%M:%S'),v["Open"],v["High"],v[2],v[3])÷
# Out:
# 2023-05-08 00:00:00 172.24175011249318 173.60986810110467 171.87226606740936 173.26034545898438 55962800.0
# 2023-05-09 00:00:00 172.81097613044236 173.3002895612627 171.36298200392997 171.53274536132812 45326900.0
# 2023-05-10 00:00:00 172.78101930661256 173.78961875220264 171.662555951991 173.3202667236328 53724500.0
# 2023-05-11 00:00:00 173.6098777368343 174.34884586801633 171.93219029433865 173.510009765625 49514700.0
# 2023-05-12 00:00:00 173.6199951171875 174.05999755859375 171.0 172.57000732421875 45497800.0
# 2023-05-15 00:00:00 173.16000366210938 173.2100067138672 171.47000122070312 172.07000732421875 37266700.0
# 2023-05-16 00:00:00 171.99000549316406 173.13999938964844 171.8000030517578 172.07000732421875 42110300.0
# 2023-05-17 00:00:00 171.7100067138672 172.92999267578125 170.4199981689453 172.69000244140625 57951600.0
# 2023-05-18 00:00:00 173.0 175.24000549316406 172.5800018310547 175.0500030517578 65496700.0
# ...

# %%
import requests
import json


#     "https://api.openweathermap.org/data/2.5/onecall
url = 'https://api.openweathermap.org/data/2.5/weather'
lat = '37.56667'
lon = '126.97806'
API_KEY = '906dcd2111a4f5131e61aed2a05a1e73'
weather_data = requests.get(f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}")
weather_data = json.loads(weather_data.text)

# %%
for i,v in weather_data.items():
    print(i,':',v)
# Out:
# coord : {'lon': 126.98, 'lat': 37.57}
# weather : [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]
# base : stations
# main : {'temp': 297, 'feels_like': 297.11, 'temp_min': 293.9, 'temp_max': 297.97, 'pressure': 1003, 'humidity': 64}
# visibility : 10000
# wind : {'speed': 3.09, 'deg': 210}
# clouds : {'all': 75}
# dt : 1686210496
# sys : {'type': 1, 'id': 8105, 'country': 'KR', 'sunrise': 1686168654, 'sunset': 1686221481}
# timezone : 32400
# id : 1835848
# name : Seoul
# cod : 200
